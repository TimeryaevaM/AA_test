# %%
#pip install category_encoders
#pip install pygini
#pip install feature_engine
#pip install scikit-optimize 

import pandas as pd
import seaborn as sns
import numpy as np
import math
import sklearn
from numpy import percentile
from scipy.stats import uniform as sp_randFloat
from scipy.stats import randint as sp_randInt
from scipy.stats import ks_2samp, kstest
from matplotlib import pyplot as plt
from feature_engine.encoding import RareLabelEncoder
from category_encoders.woe import WOEEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.isotonic import IsotonicRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.calibration import calibration_curve
from sklearn.model_selection import RandomizedSearchCV
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from pygini import gini
from skopt import BayesSearchCV

import warnings

# %%
def data_outlier(columns_list, data):
    """Функция определяет выбросы признаков и строит датафрейм"""

    data_out = pd.DataFrame(data={'name': [], 'low_range': [], 
                                  'upper_range': [], 'out_count': []})
    df_copy = data.copy()
    
    for column_name in columns_list:
        perc25 = percentile(df_copy[column_name].dropna(axis=0), 25)
        perc75 = percentile(df_copy[column_name].dropna(axis=0), 75)
        iqr = perc75 - perc25
        low_range = perc25 - 1.5 * iqr
        upper_range = perc75 + 1.5 * iqr
        out_count = df_copy.loc[((df_copy[column_name] < low_range) | 
                                 (df_copy[column_name] > upper_range)), column_name].count()

        to_append = [column_name, round(low_range, 2), round(upper_range, 2), out_count]
        data_out_length = len(data_out)
        data_out.loc[data_out_length] = to_append

    data_out = data_out.set_index('name')

    return data_out

# %%
def variable_analyze(var, cat_type, number_type, data):
    
    if var in cat_type:
        zero_sum = df.loc[(df[var]==''), var].count()
        null_sum = df[var].isna().sum()
        
        print(f'Количество пустых строк у признака: {zero_sum}')
        print(f'Количество null значений у признака: {null_sum}')
        
    else:
        outlier_df = data_outlier(number_type, df)
        null_sum = df[var].isna().sum()
        
        print(f'Количество null значений у признака: {null_sum}\n')
        print(f'Выбросы признака: \n{outlier_df.loc[var]}')

# %%
def variable_hist_plot(var, cat_type, number_type, data):
    
    df_copy = data.copy()
    
    if var in cat_type:
        plt.figure(figsize=(5,7))
        sns.countplot(y=var, data=df_copy, hue='Credit Default', order=df_copy[var].value_counts().index)
        plt.show()
        
        
    else:
        #Создаем логарифмическую переменную от исходной
        var_log = var +'_log'
        df_copy[var_log] = np.log(df_copy[var] + 1)
        
        plt.figure(figsize=(15,5))
        sns.histplot(x=var, data=df_copy, hue='Credit Default', multiple="stack")
        plt.show()     
        
        plt.figure(figsize=(15,5))
        sns.histplot(x=var_log, data=df_copy, hue='Credit Default', multiple="stack")
        plt.show()

# %%
# интервальный Джини
def interval_gini(prb_list):
    """Функция считает значение Джини на 1000 бустреп выборках из 100 элементов и записывает значения в список"""
    gini_values = []
    
    for x in range(1000):
        gini_x = gini(np.random.choice(prb_list, size=100))
        gini_values.append(gini_x)
    
    return gini_values

# %%
# КС тест
def model_ks_test(model_prb, data):
    """Функция строит распределение кумулятивной функции скоринга и выводит значение тест КС"""
    
    data_copy = pd.DataFrame(zip(data['Credit Score'],model_prb), columns=['Scoring', 'probab_default'])
    data_copy['default'] = data_copy['probab_default'].apply(lambda x: 1 if x >= 0.5 else 0)
    
    good_clients = data_copy.loc[(data_copy['default']==0), 'Scoring'].value_counts().sort_index()
    bad_clients = data_copy.loc[(data_copy['default']==1), 'Scoring'].value_counts().sort_index()
    
    scoring_list = []
    for x in range(400, 1000):
        scoring_list.append([x, good_clients.get(x, 0), bad_clients.get(x, 0)])
    
    df_scoring = pd.DataFrame(scoring_list, columns=['Scoring', 'good_count', 'bad_count'])
    df_scoring['good_cumsum'] = np.cumsum(df_scoring['good_count'])
    df_scoring['bad_cumsum'] = np.cumsum(df_scoring['bad_count'])   
    df_scoring['good_cumsum_perc'] = round(df_scoring['good_cumsum'] / df_scoring['good_count'].sum() * 100, 2)
    df_scoring['bad_cumsum_perc'] = round(df_scoring['bad_cumsum'] / df_scoring['bad_count'].sum() * 100, 2)
    
    plt.figure(figsize=(10,5))
    sns.lineplot(data=df_scoring, x='Scoring', y='good_cumsum_perc')
    sns.lineplot(data=df_scoring, x='Scoring', y='bad_cumsum_perc')
    plt.show()
    
    return ks_2samp(df_scoring['good_cumsum_perc'], df_scoring['bad_cumsum_perc'])

# %%
def calculate_psi(expected, actual, buckettype='bins', buckets=10, axis=0):
    '''Calculate the PSI (population stability index) across all variables
    Args:
       expected: numpy matrix of original values
       actual: numpy matrix of new values, same size as expected
       buckettype: type of strategy for creating buckets, bins splits into even splits, quantiles splits into quantile buckets
       buckets: number of quantiles to use in bucketing variables
       axis: axis by which variables are defined, 0 for vertical, 1 for horizontal
    Returns:
       psi_values: ndarray of psi values for each variable
    Author:
       Matthew Burke
       github.com/mwburke
       worksofchart.com
    '''

    def psi(expected_array, actual_array, buckets):
        '''Calculate the PSI for a single variable
        Args:
           expected_array: numpy array of original values
           actual_array: numpy array of new values, same size as expected
           buckets: number of percentile ranges to bucket the values into
        Returns:
           psi_value: calculated PSI value
        '''

        def scale_range (input, min, max):
            input += -(np.min(input))
            input /= np.max(input) / (max - min)
            input += min
            return input


        breakpoints = np.arange(0, buckets + 1) / (buckets) * 100

        if buckettype == 'bins':
            breakpoints = scale_range(breakpoints, np.min(expected_array), np.max(expected_array))
        elif buckettype == 'quantiles':
            breakpoints = np.stack([np.percentile(expected_array, b) for b in breakpoints])



        expected_percents = np.histogram(expected_array, breakpoints)[0] / len(expected_array)
        actual_percents = np.histogram(actual_array, breakpoints)[0] / len(actual_array)

        def sub_psi(e_perc, a_perc):
            '''Calculate the actual PSI value from comparing the values.
               Update the actual value to a very small number if equal to zero
            '''
            if a_perc == 0:
                a_perc = 0.0001
            if e_perc == 0:
                e_perc = 0.0001

            value = (e_perc - a_perc) * np.log(e_perc / a_perc)
            return(value)

        psi_value = np.sum(sub_psi(expected_percents[i], actual_percents[i]) for i in range(0, len(expected_percents)))

        return(psi_value)

    if len(expected.shape) == 1:
        psi_values = np.empty(len(expected.shape))
    else:
        psi_values = np.empty(expected.shape[axis])

    for i in range(0, len(psi_values)):
        if len(psi_values) == 1:
            psi_values = psi(expected, actual, buckets)
        elif axis == 0:
            psi_values[i] = psi(expected[:,i], actual[:,i], buckets)
        elif axis == 1:
            psi_values[i] = psi(expected[i,:], actual[i,:], buckets)

    return(psi_values)

# %%
def model_calibr_curve(model_name, model_prb, y_test, X_val, y_val):
    """Функция считает изотоническую калибровку для модели и выводит график сравнения"""

    #IsotonicRegression
    isotonic_regress = IsotonicRegression(y_min = 0, y_max = 1, out_of_bounds = 'clip').fit(model_prb, y_test)
    prb_isotonic_regress = isotonic_regress.predict(model_name.predict_proba(X_val)[:, 1])

    #Создаем calibration_curve для моделей для сравнения
    prob_true_model, prob_pred_model = calibration_curve(y_test, model_prb, n_bins=10)
    prob_true_iso, prob_pred_iso = calibration_curve(y_val, prb_isotonic_regress, n_bins=10)
    
    #Строим график
    plt.figure(figsize=(7,7))
    plt.plot([0,1], [0,1], color='grey')
    plt.plot(prob_pred_model, prob_true_model, marker='o', label=model_name)
    plt.plot(prob_pred_iso, prob_true_iso, marker='o', label='iso_model')
    plt.xlabel('Predicted probability')
    plt.ylabel('True probability in each bin')
    plt.show()

# %%
warnings.simplefilter("ignore")
RANDOM_SEED = 42

# %%
df = pd.read_csv('C:/Users/Files/GB_AA_DataScience/AA_test/train.csv')

# %%
df.sample(10)
# Out:
#         Id Home Ownership  Annual Income Years in current job  Tax Liens  \
# 5728  5728           Rent            NaN              9 years        2.0
# 5755  5755  Home Mortgage      2733758.0            10+ years        0.0
# 277    277  Home Mortgage            NaN              3 years        0.0
# 3197  3197           Rent      1175093.0              3 years        0.0
# 2244  2244  Home Mortgage            NaN              9 years        0.0
# 6246  6246           Rent       670130.0                  NaN        0.0
# 6589  6589  Home Mortgage            NaN              3 years        0.0
# 6891  6891       Own Home      1113305.0            10+ years        0.0
# 4098  4098  Home Mortgage      1355935.0            10+ years        0.0
# 6046  6046           Rent      1577152.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 5728                      6.0                     22.0             283118.0
# 5755                      5.0                     19.6             310970.0
# 277                       8.0                     21.6             887502.0
# 3197                     21.0                     15.1             469788.0
# 2244                     30.0                     17.1            1683132.0
# 6246                      7.0                     16.5             358754.0
# 6589                     11.0                     12.8             531762.0
# 6891                     29.0                     23.7            1859638.0
# 4098                      6.0                     13.8             349404.0
# 6046                      9.0                     30.5             592174.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 5728                        2.0                          81.0           0.0
# 5755                        0.0                          10.0           0.0
# 277                         0.0                           NaN           0.0
# 3197                        0.0                          70.0           0.0
# 2244                        0.0                           NaN           0.0
# 6246                        1.0                           NaN           1.0
# 6589                        0.0                           NaN           0.0
# 6891                        0.0                          40.0           0.0
# 4098                        0.0                          53.0           0.0
# 6046                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 5728  debt consolidation   Long Term             526636.0
# 5755  debt consolidation   Long Term             533126.0
# 277                other  Short Term             152988.0
# 3197  debt consolidation  Short Term             431948.0
# 2244  debt consolidation  Short Term             261954.0
# 6246  debt consolidation  Short Term             221694.0
# 6589       business loan  Short Term             340494.0
# 6891  debt consolidation  Short Term             642136.0
# 4098  debt consolidation  Short Term           99999999.0
# 6046  debt consolidation  Short Term           99999999.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 5728                229843.0       61905.0           NaN               1
# 5755                270978.0       15765.0         687.0               0
# 277                 270560.0       11270.0           NaN               1
# 3197                327009.0       12436.0         700.0               0
# 2244                357580.0       45518.0           NaN               0
# 6246                 85196.0        3217.0         739.0               0
# 6589                337079.0       45388.0           NaN               1
# 6891                626354.0       23287.0         696.0               0
# 4098                100187.0       11525.0         743.0               0
# 6046                474582.0       15772.0         742.0               0

# %%
df.shape
# Out:
# (7500, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Id                            7500 non-null   int64
#  1   Home Ownership                7500 non-null   object
#  2   Annual Income                 5943 non-null   float64
#  3   Years in current job          7129 non-null   object
#  4   Tax Liens                     7500 non-null   float64
#  5   Number of Open Accounts       7500 non-null   float64
#  6   Years of Credit History       7500 non-null   float64
#  7   Maximum Open Credit           7500 non-null   float64
#  8   Number of Credit Problems     7500 non-null   float64
#  9   Months since last delinquent  3419 non-null   float64
#  10  Bankruptcies                  7486 non-null   float64
#  11  Purpose                       7500 non-null   object
#  12  Term                          7500 non-null   object
#  13  Current Loan Amount           7500 non-null   float64
#  14  Current Credit Balance        7500 non-null   float64
#  15  Monthly Debt                  7500 non-null   float64
#  16  Credit Score                  5943 non-null   float64
#  17  Credit Default                7500 non-null   int64
# dtypes: float64(12), int64(2), object(4)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#                 Id  Annual Income    Tax Liens  Number of Open Accounts  \
# count  7500.000000   5.943000e+03  7500.000000              7500.000000
# mean   3749.500000   1.366392e+06     0.030133                11.130933
# std    2165.207842   8.453392e+05     0.271604                 4.908924
# min       0.000000   1.645970e+05     0.000000                 2.000000
# 25%    1874.750000   8.443410e+05     0.000000                 8.000000
# 50%    3749.500000   1.168386e+06     0.000000                10.000000
# 75%    5624.250000   1.640137e+06     0.000000                14.000000
# max    7499.000000   1.014934e+07     7.000000                43.000000
#
#        Years of Credit History  Maximum Open Credit  \
# count              7500.000000         7.500000e+03
# mean                 18.317467         9.451537e+05
# std                   7.041946         1.602622e+07
# min                   4.000000         0.000000e+00
# 25%                  13.500000         2.792295e+05
# 50%                  17.000000         4.781590e+05
# 75%                  21.800000         7.935015e+05
# max                  57.700000         1.304726e+09
#
#        Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# count                7500.000000                   3419.000000   7486.000000
# mean                    0.170000                     34.692600      0.117152
# std                     0.498598                     21.688806      0.347192
# min                     0.000000                      0.000000      0.000000
# 25%                     0.000000                     16.000000      0.000000
# 50%                     0.000000                     32.000000      0.000000
# 75%                     0.000000                     50.000000      0.000000
# max                     7.000000                    118.000000      4.000000
#
#        Current Loan Amount  Current Credit Balance   Monthly Debt  \
# count         7.500000e+03            7.500000e+03    7500.000000
# mean          1.187318e+07            2.898332e+05   18314.454133
# std           3.192612e+07            3.178714e+05   11926.764673
# min           1.124200e+04            0.000000e+00       0.000000
# 25%           1.801690e+05            1.142565e+05   10067.500000
# 50%           3.095730e+05            2.093230e+05   16076.500000
# 75%           5.198820e+05            3.604062e+05   23818.000000
# max           1.000000e+08            6.506797e+06  136679.000000
#
#        Credit Score  Credit Default
# count   5943.000000     7500.000000
# mean    1151.087498        0.281733
# std     1604.451418        0.449874
# min      585.000000        0.000000
# 25%      711.000000        0.000000
# 50%      731.000000        0.000000
# 75%      743.000000        1.000000
# max     7510.000000        1.000000

# %% [markdown]
# ## Рассмотрим все признаки

# %%
# Посмотрим количество уникальных значений
df.nunique()
# Out:
# Id                              7500
# Home Ownership                     4
# Annual Income                   5478
# Years in current job              11
# Tax Liens                          8
# Number of Open Accounts           39
# Years of Credit History          408
# Maximum Open Credit             6963
# Number of Credit Problems          8
# Months since last delinquent      89
# Bankruptcies                       5
# Purpose                           15
# Term                               2
# Current Loan Amount             5386
# Current Credit Balance          6592
# Monthly Debt                    6716
# Credit Score                     268
# Credit Default                     2
# dtype: int64

# %% [markdown]
# Распределим признаки начально на категориальные и числовые
#
# Признак id не рассматриваем, так как его удалим

# %%
categorial_var = ['Home Ownership', 'Years in current job', 'Tax Liens',
                  'Number of Credit Problems', 'Bankruptcies', 'Purpose', 'Term']
number_var = df.columns.drop(['Id', 'Home Ownership', 'Tax Liens', 'Number of Credit Problems', 
                              'Years in current job', 'Bankruptcies', 'Purpose', 'Term', 'Credit Default']).to_list()

# %% [markdown]
# #### Home Ownership

# %%
df['Home Ownership'] = df['Home Ownership'].apply(lambda x: 'Home Mortgage' if x=='Have Mortgage' else x)

# %%
variable_analyze('Home Ownership', categorial_var, number_var, df)
variable_hist_plot('Home Ownership', categorial_var, number_var, df)
# Out:
# Количество пустых строк у признака: 0
# Количество null значений у признака: 0

# %% [markdown]
# #### Years in current job

# %%
variable_analyze('Years in current job', categorial_var, number_var, df)
variable_hist_plot('Years in current job', categorial_var, number_var, df)
# Out:
# Количество пустых строк у признака: 0
# Количество null значений у признака: 371

# %% [markdown]
# Замечание: Количество null Значений мало, либо удалим строки, либо сделаем преобразование

# %% [markdown]
# #### Tax Liens

# %%
variable_analyze('Tax Liens', categorial_var, number_var, df)
variable_hist_plot('Tax Liens', categorial_var, number_var, df)
# Out:
# Количество пустых строк у признака: 0
# Количество null значений у признака: 0

# %% [markdown]
# Замечание:
#
#     значение 0 имеет сильное преобладание над остальными значениями

# %% [markdown]
# #### Number of Credit Problems

# %%
variable_analyze('Number of Credit Problems', categorial_var, number_var, df)
variable_hist_plot('Number of Credit Problems', categorial_var, number_var, df)
# Out:
# Количество пустых строк у признака: 0
# Количество null значений у признака: 0

# %% [markdown]
# #### Bankruptcies

# %%
variable_analyze('Bankruptcies', categorial_var, number_var, df)
variable_hist_plot('Bankruptcies', categorial_var, number_var, df)
# Out:
# Количество пустых строк у признака: 0
# Количество null значений у признака: 14

# %% [markdown]
# Замечание:
#
#     Количество null значений невелико, скорее всего удалим

# %% [markdown]
# #### Purpose

# %%
variable_analyze('Purpose', categorial_var, number_var, df)
variable_hist_plot('Purpose', categorial_var, number_var, df)
# Out:
# Количество пустых строк у признака: 0
# Количество null значений у признака: 0

# %% [markdown]
# #### Term

# %%
variable_analyze('Term', categorial_var, number_var, df)
variable_hist_plot('Term', categorial_var, number_var, df)
# Out:
# Количество пустых строк у признака: 0
# Количество null значений у признака: 0

# %% [markdown]
# ### Рассмотрим признаки, которые имеют числовой тип

# %% [markdown]
# #### Annual Income

# %%
variable_analyze('Annual Income', categorial_var, number_var, df)
variable_hist_plot('Annual Income', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 1557
#
# Выбросы признака:
# low_range      -349353.0
# upper_range    2833831.0
# out_count          287.0
# Name: Annual Income, dtype: float64

# %% [markdown]
# Замечание:
#
#     Количество null значений велико, либо удалим значения, либо сделаем преобразование
#
#     Логарифмирование приближает распределение к нормальному

# %% [markdown]
# #### Years of Credit History

# %%
variable_analyze('Years of Credit History', categorial_var, number_var, df)
variable_hist_plot('Years of Credit History', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 0
#
# Выбросы признака:
# low_range        1.05
# upper_range     34.25
# out_count      228.00
# Name: Years of Credit History, dtype: float64

# %% [markdown]
# Замечание:
#
#     Распределение имеет очень длинный хвост
#
#     Логарифмирование приближает распределение к нормальному

# %% [markdown]
# #### Maximum Open Credit

# %%
variable_analyze('Maximum Open Credit', categorial_var, number_var, df)
variable_hist_plot('Maximum Open Credit', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 0
#
# Выбросы признака:
# low_range      -492178.5
# upper_range    1564909.5
# out_count          466.0
# Name: Maximum Open Credit, dtype: float64

# %%
#Какое количество записей с максимумом открытых кредитов = 0
df.loc[(df['Maximum Open Credit']== 0), 'Maximum Open Credit'].count()
# Out:
# 65

# %%
variable_hist_plot('Maximum Open Credit', categorial_var, number_var, 
                 df[(df['Maximum Open Credit']>0) & (df['Maximum Open Credit']<=4_000_000)])

# %% [markdown]
# Замечание:
#
#     Распределение имеет очень длинный хвост, сделаем логарифмирование, либо обрезку (выбросы), либо пометим выбросы

# %% [markdown]
# #### Number of Open Accounts

# %%
variable_analyze('Number of Open Accounts', categorial_var, number_var, df)
variable_hist_plot('Number of Open Accounts', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 0
#
# Выбросы признака:
# low_range       -1.0
# upper_range     23.0
# out_count      170.0
# Name: Number of Open Accounts, dtype: float64

# %% [markdown]
# #### Months since last delinquent

# %%
variable_analyze('Months since last delinquent', categorial_var, number_var, df)
variable_hist_plot('Months since last delinquent', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 4081
#
# Выбросы признака:
# low_range      -35.0
# upper_range    101.0
# out_count        1.0
# Name: Months since last delinquent, dtype: float64

# %% [markdown]
# Замечание : очень много null значений, скорее всего это те клиенты, у которых нет нарушений

# %% [markdown]
# #### Current Loan Amount

# %%
variable_analyze('Current Loan Amount', categorial_var, number_var, df)
variable_hist_plot('Current Loan Amount', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 0
#
# Выбросы признака:
# low_range      -329400.5
# upper_range    1029451.5
# out_count          870.0
# Name: Current Loan Amount, dtype: float64

# %%
#Какое количество записей с Current Loan Amount >= 99999999.0
df.loc[(df['Current Loan Amount']>= 99999999.0), 'Current Loan Amount'].count()
# Out:
# 870

# %%
# Так как часть значений 99999999.0 (возможно это заглушкка), ставим лимит на 90_000_000
variable_hist_plot('Current Loan Amount', categorial_var, number_var, df[df['Current Loan Amount']<99_999_999])

# %% [markdown]
# Замечание:
#
#     Обрезку по выбросам сделать

# %% [markdown]
# #### Current Credit Balance

# %%
variable_analyze('Current Credit Balance', categorial_var, number_var, df)
variable_hist_plot('Current Credit Balance', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 0
#
# Выбросы признака:
# low_range     -254968.12
# upper_range    729630.88
# out_count         440.00
# Name: Current Credit Balance, dtype: float64

# %%
#Какое количество записей с Current Credit Balance = 0
df.loc[(df['Current Credit Balance']==0), 'Current Credit Balance'].count()
# Out:
# 53

# %%
variable_hist_plot('Current Credit Balance', categorial_var, number_var, df[df['Current Credit Balance'] > 0])

# %% [markdown]
# Замечание:
#
#     Обрезку по выбросам сделать

# %% [markdown]
# #### Monthly Debt

# %%
variable_analyze('Monthly Debt', categorial_var, number_var, df)
variable_hist_plot('Monthly Debt', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 0
#
# Выбросы признака:
# low_range     -10558.25
# upper_range    44443.75
# out_count        255.00
# Name: Monthly Debt, dtype: float64

# %% [markdown]
# Замечание:
#
#     Обрезку по выбросам сделать, возможно логарифмирование

# %% [markdown]
# #### Credit Score

# %%
variable_analyze('Credit Score', categorial_var, number_var, df)
variable_hist_plot('Credit Score', categorial_var, number_var, df)
# Out:
# Количество null значений у признака: 1557
#
# Выбросы признака:
# low_range      663.0
# upper_range    791.0
# out_count      662.0
# Name: Credit Score, dtype: float64

# %%
variable_hist_plot('Credit Score', categorial_var, number_var, df[df['Credit Score'] < 6000])

# %%
# Посмотрим, как распределен дефолт у скора >= 6000

df.loc[(df['Credit Score'] >= 6000), 'Credit Default'].value_counts(dropna=False)
# Out:
# 1    400
# Name: Credit Default, dtype: int64

# %% [markdown]
# Замечание:
#
#     Часть примеров имеет null значения, скорее всего это новые клиенты, либо клиенты по которым не посчитан скор.
#     Вынести это в отдельный признак
#
#     Часть скоров имеет значение < 750, 400 записей имеет значение > 6000.
#     Скорее всего это ошибка в вычислении скора (она может быть не более 1000, и чем больше скор, тем лучше занчение дефолта должно быть, а у всех записей значение дефолта = 1

# %% [markdown]
# #### Таргет Credit Default

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='Credit Default', data=df)
plt.show()

# %% [markdown]
# ### Обработка признаков

# %%
# Обработка null значений

df.isna().sum()
# Out:
# Id                                 0
# Home Ownership                     0
# Annual Income                   1557
# Years in current job             371
# Tax Liens                          0
# Number of Open Accounts            0
# Years of Credit History            0
# Maximum Open Credit                0
# Number of Credit Problems          0
# Months since last delinquent    4081
# Bankruptcies                      14
# Purpose                            0
# Term                               0
# Current Loan Amount                0
# Current Credit Balance             0
# Monthly Debt                       0
# Credit Score                    1557
# Credit Default                     0
# dtype: int64

# %%
df[df['Annual Income'].isna()].isna().sum()
# Out:
# Id                                 0
# Home Ownership                     0
# Annual Income                   1557
# Years in current job              75
# Tax Liens                          0
# Number of Open Accounts            0
# Years of Credit History            0
# Maximum Open Credit                0
# Number of Credit Problems          0
# Months since last delinquent     874
# Bankruptcies                       2
# Purpose                            0
# Term                               0
# Current Loan Amount                0
# Current Credit Balance             0
# Monthly Debt                       0
# Credit Score                    1557
# Credit Default                     0
# dtype: int64

# %% [markdown]
# Видим, что много записей у других атрибутов, где Annual Income is NULL. Не имеет смысла заменять эти записи. Удалим их

# %%
df[df['Credit Score'] >= 6000].isna().sum()
# Удалим строки, где скор > 6000.
# Out:
# Id                                0
# Home Ownership                    0
# Annual Income                     0
# Years in current job             18
# Tax Liens                         0
# Number of Open Accounts           0
# Years of Credit History           0
# Maximum Open Credit               0
# Number of Credit Problems         0
# Months since last delinquent    216
# Bankruptcies                      3
# Purpose                           0
# Term                              0
# Current Loan Amount               0
# Current Credit Balance            0
# Monthly Debt                      0
# Credit Score                      0
# Credit Default                    0
# dtype: int64

# %%
df = df[df['Annual Income'].isna()==False]
df = df[df['Credit Score'] < 6000]

# %%
df.isna().sum()
# Out:
# Id                                 0
# Home Ownership                     0
# Annual Income                      0
# Years in current job             278
# Tax Liens                          0
# Number of Open Accounts            0
# Years of Credit History            0
# Maximum Open Credit                0
# Number of Credit Problems          0
# Months since last delinquent    2991
# Bankruptcies                       9
# Purpose                            0
# Term                               0
# Current Loan Amount                0
# Current Credit Balance             0
# Monthly Debt                       0
# Credit Score                       0
# Credit Default                     0
# dtype: int64

# %% [markdown]
# Видим, что осталось много записей с NULL у Months since last delinquent.
# Надо заменить эти значений. Также выдеим новый признак.
#
# Также есть записи с NULL у Years in current job и Bankruptcies. Можно либо удалить, либо сделать замену.

# %%
df.loc[df['Years in current job'].isna(), 'Years in current job'] = '10+ years'
df.loc[df['Months since last delinquent'].isna(), 
       'Months since last delinquent'] = round(df['Months since last delinquent'].median())
df.loc[df['Bankruptcies'].isna(), 'Bankruptcies'] = 0

# %% [markdown]
# ### Работа с признаками

# %%
#Корреляция признаков

plt.figure(figsize=(10,10))
sns.heatmap(df.corr().abs(), annot=True, fmt='.2f', cmap="Blues")
plt.show()

# %% [markdown]
# Видим, что чатсь признаков сильно коррелирует:
#
#     Annual income и monthly debt
#
#     Tax liens и Number of credit problems
#
#     Number of credit problems и Bancrupties

# %% [markdown]
# ### Выделение новых признаков

# %%
print("Categorial variables:", categorial_var, "Number variables:", number_var, sep='\n')
# Out:
# Categorial variables:
# ['Home Ownership', 'Years in current job', 'Tax Liens', 'Number of Credit Problems', 'Bankruptcies', 'Purpose', 'Term']
# Number variables:
# ['Annual Income', 'Number of Open Accounts', 'Years of Credit History', 'Maximum Open Credit', 'Months since last delinquent', 'Current Loan Amount', 'Current Credit Balance', 'Monthly Debt', 'Credit Score']

# %%
for x in categorial_var:
    df[x] = df[x].astype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5543 entries, 0 to 7497
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Id                            5543 non-null   int64
#  1   Home Ownership                5543 non-null   object
#  2   Annual Income                 5543 non-null   float64
#  3   Years in current job          5543 non-null   object
#  4   Tax Liens                     5543 non-null   object
#  5   Number of Open Accounts       5543 non-null   float64
#  6   Years of Credit History       5543 non-null   float64
#  7   Maximum Open Credit           5543 non-null   float64
#  8   Number of Credit Problems     5543 non-null   object
#  9   Months since last delinquent  5543 non-null   float64
#  10  Bankruptcies                  5543 non-null   object
#  11  Purpose                       5543 non-null   object
#  12  Term                          5543 non-null   object
#  13  Current Loan Amount           5543 non-null   float64
#  14  Current Credit Balance        5543 non-null   float64
#  15  Monthly Debt                  5543 non-null   float64
#  16  Credit Score                  5543 non-null   float64
#  17  Credit Default                5543 non-null   int64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 822.8+ KB

# %%
X = df[[*categorial_var, *number_var]]
y = df['Credit Default']

#Выделим трейн и тест
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=RANDOM_SEED)
#Выделим отдельно трейн и валид
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=RANDOM_SEED)

#Выделим массивы без обработки для проверки доп критериев
df_train = X_train.copy()
df_test = X_test.copy()

# %% [markdown]
# ### Преобразование признаков

# %%
X_train_num = X_train[number_var]
X_test_num = X_test[number_var]
X_val_num = X_val[number_var]

X_train_cat = X_train[categorial_var]
X_test_cat = X_test[categorial_var]
X_val_cat = X_val[categorial_var]

#StandardScaler
stand_scaler = StandardScaler()
X_train_num = stand_scaler.fit_transform(X_train_num)
X_test_num = stand_scaler.transform(X_test_num)
X_val_num = stand_scaler.transform(X_val_num)

#RareLabelEncoder
rle = RareLabelEncoder(tol=0.03, n_categories=2, replace_with='Rare')
X_train_cat = rle.fit_transform(X_train_cat, y_train)
X_test_cat = rle.transform(X_test_cat)
X_val_cat = rle.transform(X_val_cat)

#WOEEncoder
woe = WOEEncoder(random_state=RANDOM_SEED)
X_train_cat = woe.fit_transform(X_train_cat, y_train)
X_test_cat = woe.transform(X_test_cat)
X_val_cat = woe.transform(X_val_cat)

# Объединим обратно категориальные и числовые датасеты
X_train = np.hstack((X_train_num, X_train_cat))
X_test = np.hstack((X_test_num, X_test_cat))
X_val = np.hstack((X_val_num, X_val_cat))

# %% [markdown]
# ### PSI

# %%
print("Значения PSI для числовых признаков\n")

for var in number_var:
    psi_var = calculate_psi(df_train[var], df_test[var])
    print(f"{var:30s}: {psi_var:.5f}")
# Out:
# Значения PSI для числовых признаков
#
# Annual Income                 : 0.00398
# Number of Open Accounts       : 0.01146
# Years of Credit History       : 0.00465
# Maximum Open Credit           : 0.00134
# Months since last delinquent  : 0.01123
# Current Loan Amount           : 0.00007
# Current Credit Balance        : 0.01031
# Monthly Debt                  : 0.00353
# Credit Score                  : 0.01035

# %% [markdown]
# ### LogisticRegression

# %%
#LogisticRegression Модель без оптимизации
lr_model = LogisticRegression(random_state=RANDOM_SEED).fit(X_train, y_train)
lr_prb = lr_model.predict_proba(X_test)[:, 1]

# %%
#LogisticRegression Модель с оптимизацией гиперпараметров
lr_model = LogisticRegression(random_state=RANDOM_SEED)

param_grid = {
    'solver': ['liblinear', 'saga'],  
    'penalty': ['l1','l2'],
    'tol': (1e-5, 1e-3, 'log-uniform'),
    'C': (10, 100, 'log-uniform'),
    'fit_intercept': [True, False]
}

opt = BayesSearchCV(
    lr_model,
    param_grid,
    random_state=RANDOM_SEED,
    cv=3
)

# %%
opt.fit(X_train, y_train)
opt.best_params_
# Out:
# OrderedDict([('C', 10),
#              ('fit_intercept', True),
#              ('penalty', 'l1'),
#              ('solver', 'saga'),
#              ('tol', 1.1360828903750424e-05)])

# %%
lr_model = LogisticRegression(**opt.best_params_, random_state=RANDOM_SEED).fit(X_train, y_train)
lr_prb = lr_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# #### Feature importance

# %%
#feature importance
lr_imp = pd.Series(lr_model.coef_[0], index=df_train.columns)

plt.figure(figsize=(5,5))
lr_imp.sort_values(ascending=False).plot.bar()
plt.show()

# %% [markdown]
# #### Оценка качества модели

# %% [markdown]
# #### Индекс Джини и интервальный Джини

# %%
#Коэффициент Джини
gini_x = round(gini(lr_prb), 3)
print(f"Значение коэффициента Джини: {gini_x}")
# Out:
# Значение коэффициента Джини: 0.363

# %%
# интервальный Джини
gini_interv = interval_gini(lr_prb)

#Построим график распределения индексов Джини
plt.figure(figsize=(10,5))
plt.hist(gini_interv, bins=20)
plt.axvline(x=gini_x, color='orange', linestyle="--") 
plt.text (gini_x, 100, gini_x)
plt.title('Распределение коэффициентов Джини')
plt.show()

# %% [markdown]
# #### Оценка Колмогорова-Смирнова

# %%
model_ks_test(lr_prb, df_test)
# Out:
# KstestResult(statistic=0.125, pvalue=0.0001668273704107718)

# %% [markdown]
# #### Изотоническая калибровка и график сравнения

# %%
model_calibr_curve(lr_model, lr_prb, y_test, X_val, y_val)

# %% [markdown]
# ### SVM модель

# %%
#SVM Модель без оптимизации
svc_model = SVC(probability=True, random_state=RANDOM_SEED).fit(X_train, y_train)
svc_prb = svc_model.predict_proba(X_test)[:, 1]

# %%
#SVM Модель с оптимизацией гиперпараметров
svc_model = SVC(probability=True, random_state=RANDOM_SEED)

param_grid = {
    'C': (1e-6, 100.0, 'log-uniform'),
#    'degree': (1, 5),
#    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': [1e-6, 100.0, 'log-uniform']
}


opt = BayesSearchCV(
    svc_model,
    param_grid,
    random_state=RANDOM_SEED,
    cv=3
)

# %%
opt.fit(X_train, y_train)
opt.best_params_
# Out:
# OrderedDict([('C', 83.36992814578494), ('gamma', 0.014289381660687528)])

# %%
svc_model = SVC(**opt.best_params_, probability=True, random_state=RANDOM_SEED).fit(X_train, y_train)
svc_prb = svc_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# #### Feature importance

# %%
#feature importance
if svc_model.kernel == 'linear':
    svc_imp = pd.Series(svc_model.coef_, index=df_train.columns)

    plt.figure(figsize=(5,5))
    svc_imp.sort_values(ascending=False).plot.bar()
    plt.show()
else:
    print("Feature importance works only for SVM with linear kernel")
# Out:
# Feature importance works only for SVM with linear kernel

# %% [markdown]
# #### Коэффициент Джини и интервальный Джини

# %%
gini_x = round(gini(svc_prb), 3)
print(f"Значение коэффициента Джини: {gini_x}")
# Out:
# Значение коэффициента Джини: 0.216

# %%
# интервальный Джини
gini_interv = interval_gini(svc_prb)

#Построим график распределения индексов Джини
plt.figure(figsize=(10,5))
plt.hist(gini_interv, bins=20)
plt.axvline(x=gini_x, color='orange', linestyle="--") 
plt.text (gini_x, 100, gini_x)
plt.title('Распределение коэффициентов Джини')
plt.show()

# %% [markdown]
# #### Оценка Колмогорова-Смирнова

# %%
model_ks_test(svc_prb, df_test)
# Out:
# KstestResult(statistic=0.14, pvalue=1.5177728391901887e-05)

# %% [markdown]
# #### Изотоническая калибровка и график сравнения

# %%
model_calibr_curve(svc_model, svc_prb, y_test, X_val, y_val)

# %% [markdown]
# ### Random Forest

# %%
#RandomForestClassifier Модель без оптимизации
rfc_model = RandomForestClassifier(random_state=RANDOM_SEED).fit(X_train, y_train)
rfc_prb = rfc_model.predict_proba(X_test)[:, 1]

# %%
#RandomForestClassifier Модель с оптимизацией гиперпараметров
rfc_model = RandomForestClassifier(random_state=RANDOM_SEED)

param_grid = {
        'n_estimators': (5,1000),
#        'max_features': ['auto','sqrt'],
        'max_depth': (2,90),
        'min_samples_split': (2,10),
#        'min_samples_leaf': (1,7),
        'bootstrap': ["True","False"]
}

opt = BayesSearchCV(
    rfc_model,
    param_grid,
    random_state=RANDOM_SEED,
    cv=3
)

# %%
opt.fit(X_train, y_train)
opt.best_params_
# Out:
# OrderedDict([('bootstrap', 'False'),
#              ('max_depth', 12),
#              ('min_samples_split', 10),
#              ('n_estimators', 51)])

# %%
rfc_model = RandomForestClassifier(**opt.best_params_, random_state=RANDOM_SEED).fit(X_train, y_train)
rfc_prb = rfc_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# #### Feature importance Gini

# %%
#Gini importance
rfc_imp = pd.Series(rfc_model.feature_importances_, index=df_train.columns)

plt.figure(figsize=(5,5))
rfc_imp.sort_values(ascending=False).plot.bar()
plt.show()

# %% [markdown]
# #### Коэффициент Джини

# %%
gini_x = round(gini(rfc_prb), 3)
print(f"Значение коэффициента Джини: {gini_x}")
# Out:
# Значение коэффициента Джини: 0.336

# %%
# интервальный Джини
gini_interv = interval_gini(rfc_prb)

#Построим график распределения индексов Джини

plt.figure(figsize=(10,5))
plt.hist(gini_interv, bins=20)
plt.axvline(x=gini_x, color='orange', linestyle="--") 
plt.text (gini_x, 100, gini_x)
plt.title('Распределение коэффициентов Джини')
plt.show()

# %% [markdown]
# #### Оценка Колмогорова-Смирнова

# %%
model_ks_test(rfc_prb, df_test)
# Out:
# KstestResult(statistic=0.12, pvalue=0.00034899222851716977)

# %% [markdown]
# #### Изотоническая калибровка и график сравнения

# %%
model_calibr_curve(rfc_model, rfc_prb, y_test, X_val, y_val)

# %% [markdown]
# ### LGBMClassifier

# %%
#LGBMClassifier Модель без оптимизации
lgbmc_model = LGBMClassifier(importance_type='gain', random_state=RANDOM_SEED).fit(X_train, y_train)
lgbmc_prb = lgbmc_model.predict_proba(X_test)[:, 1]

# %%
#LGBMClassifier Модель с оптимизацией гиперпараметров
lgbmc_model = LGBMClassifier(importance_type='gain', random_state=RANDOM_SEED)

param_grid = {
        'learning_rate': (0.01, 1.0, 'log-uniform'),
        'num_leaves': (2, 100),
        'max_depth': (0, 100),
        'n_estimators': (10, 1000),
}

opt = BayesSearchCV(
    lgbmc_model,
    param_grid,
    random_state=RANDOM_SEED,
    cv=3
)

# %%
opt.fit(X_train, y_train)
opt.best_params_
# Out:
# OrderedDict([('learning_rate', 0.026790533576124733),
#              ('max_depth', 0),
#              ('n_estimators', 428),
#              ('num_leaves', 2)])

# %%
lgbmc_model = LGBMClassifier(**opt.best_params_, importance_type='gain', random_state=RANDOM_SEED).fit(X_train, y_train)
lgbmc_prb = lgbmc_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# #### Feature importance Gain (Gini)

# %%
lgbmc_imp = pd.Series(lgbmc_model.feature_importances_, index=df_train.columns)

plt.figure(figsize=(5,5))
lgbmc_imp.sort_values(ascending=False).plot.bar()
plt.show()

# %% [markdown]
# #### Коэффициент Джини

# %%
gini_x = round(gini(lgbmc_prb), 3)
print(f"Значение коэффициента Джини: {gini_x}")
# Out:
# Значение коэффициента Джини: 0.317

# %% [markdown]
# #### Оценка Колмогорова-Смирнова

# %%
model_ks_test(lgbmc_prb, df_test)
# Out:
# KstestResult(statistic=0.175, pvalue=1.9336585428696407e-08)

# %% [markdown]
# #### Интервальный Джини

# %%
gini_interv = interval_gini(lgbmc_prb)

#Построим график распределения индексов Джини
plt.figure(figsize=(10,5))
plt.hist(gini_interv, bins=20)
plt.axvline(x=gini_x, color='orange', linestyle="--") 
plt.text (gini_x, 100, gini_x)
plt.title('Распределение коэффициентов Джини')
plt.show()

# %% [markdown]
# #### Изотоническая калибровка и график сравнения

# %%
model_calibr_curve(lgbmc_model, lgbmc_prb, y_test, X_val, y_val)

# %% [markdown]
# # Сделать один график для всех моделей
